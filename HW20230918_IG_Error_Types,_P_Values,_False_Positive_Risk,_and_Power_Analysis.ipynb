# %% [markdown]
# <a href="https://colab.research.google.com/github/igolynker/NGG605/blob/main/HW20230918_IG_Error_Types%2C_P_Values%2C_False_Positive_Risk%2C_and_Power_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PennNGG/Quantitative-Neuroscience/blob/master/Concepts/Python/Error%20Types%2c%20P%2dValues%2c%20False%2dPositive%20Risk%2c%20and%20Power%20Analysis.ipynb)

# %% [markdown]
# # Definitions

# %% [markdown]
# ## Outcomes

# %% [markdown]
# In general, you can think of four possible outcomes of an experiment relative to a Null Hypothesis (H0):
#
# 1\. **False positive**: $H_0$ is true and $H_0$ is rejected. This outcome is called a **Type I error**, and its rate of occurrence is usually denoted as $\alpha$.
#
# 2\. **True negative**: $H_0$ is true and $H_0$ is not rejected. This outcome is the complement of a false positive error (i.e., it is the only other possibility when $H_0$ is true) and thus its rate of occurrence is usually denoted as $1-\alpha$.
#
# 3\. **False negative:** $H_0$ is false and $H_0$ is not rejected. This outcome is called a **Type II error**, and its rate of occurrence is usually denoted as $\beta$.
#
# 4\. **True positive**: $H_0$ is false and $H_0$ is rejected. This outcome is the complement of a false negative error (i.e., it is the only other possibility when $H_0$ is false) and thus its rate of occurrence is usually denoted as $1-\beta$.

# %% [markdown]
# ## *p*-values

# %% [markdown]
# A *p* value describes the probability of obtaining your data (more precisely the value of the test statistic you are using to summarize your data), given the assumption that the Null hypothesis ($H_0$) is true. It is typically related to the concepts listed above by comparing its value to a rejection threshold equal to $\alpha$, the Type I error rate you have defined conditioned on the Null hypothesis being true; i.e., reject $H_0$ if $p<\alpha$ (note that this formulation does not imply that your obtained *p* value or chosen $\alpha$ quantifies the probability that your data represents a false positive, [because knowing that would require knowing the prior probability that the Null hypothesis is true](https://colab.research.google.com/drive/1HW0L_d5Wpod3jbnY3iG7mLhMG6yWHvF2?usp=sharing)).
#
# See "Additional Resources" below for links to paper arguing that *p*-values are over-used, mis-interpreted, and/or should be abandoned completely. Despite the arguments put forward in those papers, *p*-values remain prevalent, and it is very likely you will use them in your studies. When doing so, the following concepts/approaches are important to use, whenever possible.

# %% [markdown]
# # Getting Started with Code

# %% [markdown]
# Matlab code is found in the [NGG Statistics GitHub Repository](https://github.com/PennNGG/Statistics.git) under "Concepts/PowerAnalysisExample1.m" and "Concepts/PowerAnalysisExample2.m".
#
# Python code is included below. First run the code cell just below to make sure all of the required Python modules are loaded, then you can run the other cell(s).

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from statsmodels.stats.power import TTestIndPower

# %% [markdown]
# # False-positive risk and Type I errors

# %% [markdown]
# False-positive risk is used to estimate the probably that an experiment will reject the Null hypothesis, given an estimate of the probability that the Null hypothesis is actually true; that is, the probability that it will produce a Type I error, corresponding to a false positive ($\alpha$) and complementary to a true negative ($1-\alpha$). **In general, false-positive risk is estimated in advance of conducting the experiment to help justify your experimental design, not post hoc to help justify the statistical reliability of your findings.**
#
# Because here we are considering the probability of a hypothesis being true, we use a [Bayesian](https://colab.research.google.com/drive/1HW0L_d5Wpod3jbnY3iG7mLhMG6yWHvF2?usp=sharing) approach to compute the false-positive risk as:
#
# $FPR=\frac{p\pi_0}{p\pi_0+(1-\beta)(1-\pi_0)}$
#
# where *p* is the p-value you are using, $\pi_0$ is the probability that the Null hypothesis is true based on prior evidence, and $(1−\beta)$ is the expected true-positive rate or study power (see below). Because $\pi_0$ can be difficult to know, it is sometimes assumed to be 0.5 and used to compute the "minimum FPR."
#
# Note that for *p*=0.05, $\pi_0$=0.5, and $\beta$=0.8, the minimum FPR=0.2 -- which is much bigger than the *p* value!

# %%
p = 0.05
pi0 = 0.5
beta = 0.8

minFPR = (p*pi0)/(p*pi0+(1-beta)*(1-pi0))
print(f'minimum FPR = {minFPR:.1f}')
# Out:
# minimum FPR = 0.2

# %% [markdown]
# # Power analysis and Type II errors

# %% [markdown]
# Power analysis is used to estimate the probably that an experiment will detect an effect, given that the effect is actually present; that is, the probability that it will not produce a Type II error, corresponding to a true positive ($1-\beta$) and complementary to a false negative ($\beta$). **In general, power analysis is done in advance of conducting the experiment to help justify your experimental design, not post hoc to help justify the statistical reliability of your findings.**
#
# A power analysis is based on four quantities that you must know, guess at, or figure out before you can do the calculation:
#
# 1\. Effect size: the magnitude of your test statistic that you might expect to obtain in your experiment; e.g., a Pearson's correlation coefficient of 0.4.
#
# 2\. Sample size: the number of observations in the experimental sample you plan to obtain.
#
# 3\. Significance level: the p-value you will use in your hypothesis testing, usually $\alpha$.
#
# 4\. Statistical power: the power you wish to obtain, usually $1-\beta$

# %% [markdown]
# ## Example 1 (Button et al 2013)

# %% [markdown]
# Below we will write some code to play with the analysis shown in Fig. 1 of:
#
# Button et al (2013), [Power failure: why small sample size undermines the reliability of neuroscience](https://www.nature.com/articles/nrn3475), Nature Reviews Neuroscience.
#
# ![](https://drive.google.com/uc?export=view&id=1K9iRvlNRzqbFCaaGVVW6W6Y1UMYVN_DT)
#
# **Figure legend**: Statistical power of a replication study. a | If a study finds evidence for an effect at p=0.05, then the difference between the mean of the null distribution (indicated by the solid blue curve) and the mean of the observed distribution (dashed blue curve) is 1.96×sem. b | Studies attempting to replicate an effect using the same sample size as that of the original study would have roughly the same sampling variation (that is, sem) as in the original study. Assuming, as one might in a power calculation, that the initially observed effect we are trying to replicate reflects the true effect, the potential distribution of these replication effect estimates would be similar to the distribution of the original study (dashed green curve). A study attempting to replicate a nominally significant effect (p~0.05), which uses the same sample size as the original study, would therefore have (on average) a 50% chance of rejecting the null hypothesis (indicated by the coloured area under the green curve) and thus only 50% statistical power. c | We can increase the power of the replication study (coloured area under the orange curve) by increasing the sample size so as to reduce the sem. Powering a replication study adequately (that is, achieving a power ?80%) therefore often requires a larger sample size than the original study, and a power calculation will help to decide the required size of the replication sample.

# %%
# Assume that an original study identified an effect size,
#   representing the difference in the mean value of a test distribution
#   versus a null distribution, divided by their common standard deviation
#   (i.e., the z-score of their difference), at exactly p=0.05. Remember
#   that these are distributions of mean values, so the standard deviations
#   of these distributions represent standard errors of the mean. For a
#   two-tailed test, this p-value implies that 0.975 of the area of the
#   null distribtion is less than the effect size:
effect_size = st.norm.ppf(0.975)

# We can now reproduce the first panel:
plt.figure(figsize=(10, 5))
mu_0 = 0
sem = 1      # make it easy by assuming sem=1
mu_1 = effect_size*sem
bin_size = 0.01
x_axis = np.arange(-4, 6+bin_size, bin_size)
x_edges = np.arange(x_axis[0]-bin_size/2, x_axis[-1]+bin_size, bin_size)
plt.plot([mu_0, mu_0], [0, 0.45], 'k-')
plt.plot([mu_1, mu_1], [0, 0.45], 'k-')
plt.plot(x_axis, st.norm.pdf(x_axis, mu_0, sem), 'b-')
plt.plot(x_axis, st.norm.pdf(x_axis, mu_1, sem), 'b--')
plt.xlabel('value')
plt.ylabel('probability')
plt.show()

# Now what happens when we try to replicate the result under the exact
#   same conditions? Let's simulate N experiments:
N = 100000

# In each simulated experiment, we end up with a mean value that comes
#   from the experimental distribution, and we only reject the Null
#   hypothesis if the value is greater than or equal to the previous effect size:
outcomes = np.random.normal(mu_1, sem, N)
outcome_is_positive = outcomes >= effect_size
print(f'{np.count_nonzero(outcome_is_positive)} positive outcomes out \
  of {N} experiments ({np.count_nonzero(outcome_is_positive)/N*100:.2f} pct)')

# We can plot these results as a normalized histogram
counts_no_effect, _ = np.histogram(outcomes[np.logical_not(outcome_is_positive)], bins=x_edges)
counts_effect, _    = np.histogram(outcomes[outcome_is_positive], bins=x_edges)
counts_all, _       = np.histogram(outcomes, bins=x_edges)
normalizer          = np.trapz(counts_all, dx=bin_size)

# Plot it
plt.figure(figsize=(10, 5))
plt.bar(x_axis, counts_no_effect/normalizer, width=0.01, color='lightgray')
plt.bar(x_axis, counts_effect/normalizer, width=0.01, color='gray')
plt.plot([mu_0, mu_0], [0, 0.45], 'k-')
plt.plot([mu_1, mu_1], [0, 0.45], 'k-')
plt.plot(x_axis, st.norm.pdf(x_axis, mu_0, sem), 'b-')
plt.plot(x_axis, st.norm.pdf(x_axis, mu_1, sem), 'b--')
plt.xlabel('value')
plt.ylabel('probability')
plt.show()
# Out:
# 49991 positive outcomes out   of 100000 experiments (49.99 pct)

# %%
# We can increase the power by increasing the signal-to-noise ratio (SNR) of
#   our sample, via a reduction in sem and assuming the same mean effect size.
#   The figure in the paper is confusing, because increasing SNR would narrow
#   *both* distributions (because we assume that the two hypotheses differ only
#   by their mean value, not the STD of the distributions). It is the change in
#   both distributions that explains why you would be less likely to reject the
#   Null hypothesis for the same effect size under these conditions.
#
# Also note that sem depends on both the number of samples (N) and the STD of
#   the sampled distribution, so we need to define N or STD to be able to
#   express sem in terms of the other of those two values.

# We can use a power analysis to find the new sem. The key point is that a
#   power analysis describes a relationship between the effect size and the
#   power -- so we can define a particular power to compute the effect size.
#   In this case, this computation is equivalent to doing a z test with one
#   sample and a power of 80%, which can be computed as follows (which is
#   basically computing: what is the mean of a standard normal distribution
#   that has 80% of its mass >= the cutoff for the null distribution at z=0.975?)
power = 0.8
new_effect_size = st.norm.ppf(0.975) - st.norm.ppf(1-power)

# This effect size is again the z-score, given the same mean difference
#   as above and the new sem -- so we can use it to compute the new sem:
old_effect_size = st.norm.ppf(0.975)
old_sem = 1
mu_0 = 0
mu_1 = effect_size*old_sem
new_sem = (mu_1-mu_0)/new_effect_size

# To show that this is the case, let's try a bunch of sems and find the
#   value that corresponds to when 80% of the effect distribution is >= the
#   p=0.05 cutoff for the null distribution

# Try a bunch of sems, smaller than before (i.e., <1)
sems = np.arange(0.01, 1, 0.01)
vals = np.zeros(np.size(sems))

# Loop through them
for idx, val in enumerate(sems):

   # The probability of not rejecting the null hypothesis when the null
   #  hypothesis is false is the mass of the effect distribution, which still
   #  has a mean value of effectSize but now has the given sem, that is to the
   #  right of the new cutoff
   new_cutoff = st.norm.ppf(0.975, mu_0, val)
   vals[idx] = 1 - st.norm.cdf(new_cutoff, effect_size, val)

# Plot it
plt.figure(figsize=(10, 5))
plt.plot(sems, vals, 'o', color='lightgray')
val_indices = np.flatnonzero(vals<=0.8)
new_sem2 = sems[val_indices[0]]
plt.plot([new_sem2, new_sem2], [0, 0.8], 'r-', linewidth=2)
plt.plot([0, new_sem2], [0.8, 0.8], 'r-', linewidth=2)
plt.plot(new_sem, 0.8, 'bo', markerfacecolor='b', markersize=10)
plt.xlabel('sem')
plt.ylabel('probability false negative')
plt.axis([0, 1, 0, 1.1])
plt.show()

# %%
# Now do the simulated experiments as above, but with the new distributions
N = 100000
power = 0.8
new_effect_size = st.norm.ppf(0.975) - st.norm.ppf(1-power)
old_sem = 1
mu_0 = 0
mu_1 = effect_size*old_sem
new_sem = (mu_1-mu_0)/new_effect_size

bin_size = 0.01
x_axis = np.arange(-4, 6+bin_size, bin_size)
x_edges = np.arange(x_axis[0]-bin_size/2, x_axis[-1]+bin_size, bin_size)

outcomes = np.random.normal(mu_1, new_sem, N)
outcome_is_positive = outcomes >= st.norm.ppf(0.975, mu_0, new_sem)
print(f'{np.count_nonzero(outcome_is_positive)} positive outcomes out of \
  {N} experiments ({np.count_nonzero(outcome_is_positive)/N*100:.2f} pct)')

# We can plot these results as a normalized histogram
counts_no_effect, _ = np.histogram(outcomes[np.logical_not(outcome_is_positive)], bins=x_edges)
counts_effect, _    = np.histogram(outcomes[outcome_is_positive], bins=x_edges)
counts_all, _       = np.histogram(outcomes, bins=x_edges)
normalizer          = np.trapz(counts_all, dx=bin_size)

# Plot it
plt.figure(figsize=(10, 5))
plt.bar(x_axis, counts_no_effect/normalizer, width=0.01, color='lightgray')
plt.bar(x_axis, counts_effect/normalizer, width=0.01, color='gray')
plt.plot([mu_0, mu_0], [0, 0.6], 'k-')
plt.plot([mu_1, mu_1], [0, 0.6], 'k-')
plt.plot(x_axis, st.norm.pdf(x_axis, mu_0, new_sem), 'b-')
plt.plot(x_axis, st.norm.pdf(x_axis, mu_1, new_sem), 'b--')
plt.xlabel('value')
plt.ylabel('probability')
plt.show()
# Out:
# 79975 positive outcomes out of   100000 experiments (79.97 pct)

# %% [markdown]
# ## Example 2 (Joshi et al 2016)

# %% [markdown]
# Power analyses for a relationship between pupil diameter and neural activity in the locus coeruleus (LC), as shown in Fig. 3 of:
#
# Joshi S, Li Y, Kalwani R, Gold JI (2016) [Relationships between pupil diameter and neuronal activity in the locus coeruleus, colliculi, and cingulate cortex](https://www.sciencedirect.com/science/article/pii/S089662731501034X?via%3Dihub). Neuron 89: 221-34.
#
# <div>
# <img src=https://drive.google.com/uc?export=view&id=1mIXmZBi7LNQlq3H1uAmEq0Az-uFAL1Kd width=250\>
# <div>
#
# **Figure legend**. Trial-by-Trial Associations between Mean Pupil Diameter and LC Spike Rate
#
# (A–C) Example sessions. Per-trial mean pupil diameter (A) and spike rate (B) are each plotted as a function of the time of the beginning of stable fixation in the given trial, with respect to the beginning of the session. Lines are linear fits; (C) shows residuals to these fits. The line is a linear fit to the paired residuals, representing the partial correlation between pupil diameter and spike rate, accounting for linear drifts of each variable as a function of time within the session.
#
# (D) Distributions of Spearman’s partial correlations (ρ) between trial-by-trial pupil diameter and spike rate, accounting for time within the session, for each session from each monkey and each brain region, as indicated. Darker/lighter symbols indicate ρ > 0/ρ < 0. Filled symbols indicate H0: ρ = 0, p < 0.05. Counts (percentages) of significant positive/negative effects are shown for each monkey (per-monkey percentages for positive or negative effects were indistinguishable between LC+ and IC but were different for SCi, including fewer positive effects for both monkeys and more negative effects for monkey Ci; chi-square test, p < 0.05). Black symbols indicate the example sessions above. Scatter along the abscissa is arbitrary, for readability. Horizontal lines are medians; thick lines indicate H0: median = 0, Wilcoxon rank-sum test, p < 0.05.

# %% [markdown]
# ### Exercise

# %% [markdown]
# Do a post-hoc power analysis to determine the number of data samples needed to achieve 80% power for a series of possible effect sizes. Notes and tips:
#
# 1. Given that the data have already been collected, note that this is technically a "post-hoc" power analysis and is for demonstration purposes only. Normally these analyses must be done **before** collecting data.
# 2. Assume that a "data sample" is simply the non-parametric correlation coefficient between pupil diameter and LC activty measured in a given session.
# 3. Thus, to obtain a null distribution of these data samples, compute the correlation coefficients on simulated data that are independently generated from Poisson (for LC spiking data) and Gaussian (for pupil data)distributions.
# 4. Then plot n (number of data samples, corresponding to correlation coefficients measured in a single expermental session) needed for 80% power as a function of effect sizes.
# 5. To compute power, you can use TTestIndPower in Python, or sampsizepwr in Matlab

# %%
#1. import from scipy.stats import spearmanr
from scipy.stats import spearmanr
# 2. Obtain simulated data null distribution
N = 1000
correlations = [0]*N #make an empty list for 1000 values of spearman correlation can alternatively use np. zeros(1000)
#simulate the following in a for loop N times (1000 for example) to obtain a distribution of correlation coefficients
for i in range(N):
#a. Simulate data from a Poisson distribution (for LC spiking data)
    LC_spike_data = np.random.poisson(3, 100)
    #b. Simulate data from a Gaussian (for pupil data)
    pupil_data = np.random.normal(3, 1, 100)
    cur_correlation = st.spearmanr(LC_spike_data, pupil_data)
    # correlations.append(cur_correlation[0]) #append only the correlation value (gives a few values per loop, including p)
    correlations[i] = cur_correlation[0]
#print(correlations)
#print(len(correlations)) #check length of loop
#plot the distribution (from ChatGPT "how to plot a correlations distribution")
plt.hist(correlations, bins=100, color='gray', alpha=0.7)
plt.title('Distribution of Correlation Coefficients')
plt.xlabel('Correlation Coefficient')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
#3. now we have a  list with 1000 simulated non-parametric corrleation coefficients
#let's treat these correlation coefficients as the variable effct sizes
sample_sizes = [] #create an empty list to which we will append the growing list of sample sizes per each correlation coefficient
for j in correlations:
    effect_size =  j # Desired effect size
    print("Effect size: ", j)
    alpha = 0.05  # Significance level
    power = 0.80  # Desired power
    power_analysis = TTestIndPower() #this is how you deal wih an instance method.
    sample_size = power_analysis.solve_power(effect_size=effect_size, power=power, alpha=alpha, ratio=1, alternative='two-sided')
    sample_sizes.append(sample_size)

    print(f"Required Sample Size: {sample_size:.2f}")
print(sample_sizes) #check the list of all sample sizes

# Create a line plot to visualize the relationship between effect sizes and sample sizes for 80% power
plt.figure(figsize=(10, 6))
plt.scatter(correlations, sample_sizes, marker='o', color='pink')
plt.title('Sample Size Required as a Function of Effect Size for 80% Power')
plt.xlabel('Effect Size')
plt.ylabel('Sample Size Required')
plt.grid(True)
plt.ylim(0, 10000000)
plt.show()
# Out:
# Effect size:  0.06318040440925267
# Required Sample Size: 3933.49
# Effect size:  -0.13473920541541864
# Required Sample Size: 865.63
# Effect size:  -0.10222513073096091
# Required Sample Size: 1503.14
# Effect size:  0.004695358383897046
# Required Sample Size: 712032.32
# Effect size:  0.029580781299379952
# Required Sample Size: 17940.75
# Effect size:  0.03222843469884621
# Required Sample Size: 15114.22
# Effect size:  -0.014650440912918963
# Required Sample Size: 73137.64
# Effect size:  -0.184049140519817
# Required Sample Size: 464.38
# Effect size:  0.10255808739045255
# Required Sample Size: 1493.40
# Effect size:  -0.10386526287547944
# Required Sample Size: 1456.07
# Effect size:  -0.10813819929390124
# Required Sample Size: 1343.35
# Effect size:  0.11967755158720698
# Required Sample Size: 1096.96
# Effect size:  -0.030370353373240837
# Required Sample Size: 17020.07
# Effect size:  -0.10344156751379312
# Required Sample Size: 1468.02
# Effect size:  -0.2511736952214435
# Required Sample Size: 249.79
# Effect size:  0.08213287579215894
# Required Sample Size: 2327.99
# Effect size:  -0.05699545352739743
# Required Sample Size: 4833.29
# Effect size:  0.10129938719556136
# Required Sample Size: 1530.72
# Effect size:  0.03509820192032712
# Required Sample Size: 12743.82
# Effect size:  -0.16567502846513502
# Required Sample Size: 572.87
# Effect size:  0.04204027797704784
# Required Sample Size: 8882.85
# Effect size:  -0.17962189968869297
# Required Sample Size: 487.50
# Effect size:  -0.008819669210700992
# Required Sample Size: 201806.01
# Effect size:  -0.27146817157647213
# Required Sample Size: 213.97
# Effect size:  0.15361767963588346
# Required Sample Size: 666.16
# Effect size:  0.04358593510858683
# Required Sample Size: 8264.08
# Effect size:  0.0015294312280010828
# Required Sample Size: 6710838.20
# Effect size:  -0.07581044369348836
# Required Sample Size: 2732.32
# Effect size:  0.01813744241128956
# Required Sample Size: 47719.21
# Effect size:  0.06428583163621811
# Required Sample Size: 3799.41
# Effect size:  0.05868728592823668
# Required Sample Size: 4558.69
# Effect size:  -0.0397499274257728
# Required Sample Size: 9935.87
# Effect size:  0.02392771118135324
# Required Sample Size: 27418.87
# Effect size:  0.04101462950200184
# Required Sample Size: 9332.62
# Effect size:  0.05004637579912175
# Required Sample Size: 6268.42
# Effect size:  0.04427646547162197
# Required Sample Size: 8008.35
# Effect size:  -0.015482269869002965
# Required Sample Size: 65489.81
# Effect size:  -0.11454024280186448
# Required Sample Size: 1197.48
# Effect size:  -0.09156018530728434
# Required Sample Size: 1873.47
# Effect size:  0.10978169375378989
# Required Sample Size: 1303.46
# Effect size:  0.09183668435642474
# Required Sample Size: 1862.21
# Effect size:  0.10928544096790437
# Required Sample Size: 1315.31
# Effect size:  -0.012022283806290161
# Required Sample Size: 108609.17
# Effect size:  0.08486197230173294
# Required Sample Size: 2180.73
# Effect size:  -0.0172722284564225
# Required Sample Size: 52619.63
# Effect size:  -0.002900858995613654
# Required Sample Size: 1865449.94
# Effect size:  0.05021298213531163
# Required Sample Size: 6226.90
# Effect size:  0.11297591009029499
# Required Sample Size: 1230.85
# Effect size:  0.08514343013594117
# Required Sample Size: 2166.34
# Effect size:  -0.06677042660827706
# Required Sample Size: 3521.98
# Effect size:  0.030060512891284093
# Required Sample Size: 17372.72
# Effect size:  -0.2090416366460651
# Required Sample Size: 360.19
# Effect size:  0.10170744187454421
# Required Sample Size: 1518.47
# Effect size:  -0.12818148288375877
# Required Sample Size: 956.36
# Effect size:  0.08333015498879198
# Required Sample Size: 2261.61
# Effect size:  0.08946976424594083
# Required Sample Size: 1961.99
# Effect size:  0.08078562894821381
# Required Sample Size: 2406.26
# Effect size:  -0.0050871938459785175
# Required Sample Size: 606569.72
# Effect size:  0.09587494098324027
# Required Sample Size: 1708.72
# Effect size:  -0.006532020604080889
# Required Sample Size: 367910.90
# Effect size:  -0.08856771743694751
# Required Sample Size: 2002.14
# Effect size:  0.02560135380159365
# Required Sample Size: 23951.25
# Effect size:  0.05613340806706236
# Required Sample Size: 4982.85
# Effect size:  0.062444398409671524
# Required Sample Size: 4026.74
# Effect size:  -0.06822507468684923
# Required Sample Size: 3373.43
# Effect size:  -0.0588941018602211
# Required Sample Size: 4526.74
# Effect size:  -0.14911463614354478
# Required Sample Size: 706.95
# Effect size:  -0.19663233406627692
# Required Sample Size: 406.96
# Effect size:  0.07679128571758778
# Required Sample Size: 2662.99
# Effect size:  -0.034474859499316085
# Required Sample Size: 13208.79
# Effect size:  -0.026548090601219588
# Required Sample Size: 22273.51
# Effect size:  0.0004703437060007085
# Required Sample Size: 70958748.09
# Effect size:  0.01719310298940853
# Required Sample Size: 53105.06
# Effect size:  0.13710137610705475
# Required Sample Size: 836.09
# Effect size:  0.0006578687092117381
# Required Sample Size: 36270885.95
# Effect size:  -0.00868292569972125
# Required Sample Size: 208212.33
# Effect size:  0.14390138577863557
# Required Sample Size: 759.03
# Effect size:  0.05333438189940429
# Required Sample Size: 5519.47
# Effect size:  0.0753145271959945
# Required Sample Size: 2768.41
# Effect size:  -0.12079982902736876
# Required Sample Size: 1076.69
# Effect size:  0.04087532149567451
# Required Sample Size: 9396.34
# Effect size:  0.15419895494790473
# Required Sample Size: 661.16
# Effect size:  0.10161438273069195
# Required Sample Size: 1521.25
# Effect size:  -0.2234669874968805
# Required Sample Size: 315.31
# Effect size:  0.02730419166291944
# Required Sample Size: 21057.06
# Effect size:  0.011617990380356462
# Required Sample Size: 116299.59
# Effect size:  -0.03640729120485581
# Required Sample Size: 11843.91
# Effect size:  0.027112374827002003
# Required Sample Size: 21356.05
# Effect size:  -0.18199269837545665
# Required Sample Size: 474.91
# Effect size:  -0.018019635771519694
# Required Sample Size: 48345.18
# Effect size:  0.002073640648130461
# Required Sample Size: 3650646.09
# Effect size:  0.10428952796449104
# Required Sample Size: 1444.26
# Effect size:  0.002112310675491706
# Required Sample Size: 3518205.02
# Effect size:  0.070728666486483
# Required Sample Size: 3138.91
# Effect size:  0.048099013661681386
# Required Sample Size: 6786.19
# Effect size:  -0.028492937143612125
# Required Sample Size: 19336.76
# Effect size:  0.0771040128754709
# Required Sample Size: 2641.44
# Effect size:  -0.12923995432828242
# Required Sample Size: 940.78
# Effect size:  -0.1777675934950948
# Required Sample Size: 497.70
# Effect size:  0.07753214836802415
# Required Sample Size: 2612.36
# Effect size:  0.11476985068204024
# Required Sample Size: 1192.70
# Effect size:  0.001633937088242389
# Required Sample Size: 5879846.96
# Effect size:  0.06938312285547144
# Required Sample Size: 3261.80
# Effect size:  -0.026246830148183475
# Required Sample Size: 22787.74
# Effect size:  0.00034133774492788754
# Required Sample Size: 134731140.78
# Effect size:  -0.11893372382853584
# Required Sample Size: 1110.71
# Effect size:  -0.05838951159927345
# Required Sample Size: 4605.30
# Effect size:  0.12612969121182646
# Required Sample Size: 987.70
# Effect size:  -0.04203537008973688
# Required Sample Size: 8884.93
# Effect size:  -0.0002378536197766985
# Required Sample Size: 277470668.93
# Effect size:  0.1306016353794177
# Required Sample Size: 921.28
# Effect size:  -0.0340063166574832
# Required Sample Size: 13575.26
# Effect size:  0.025520411705089133
# Required Sample Size: 24103.41
# Effect size:  -0.06443425276358969
# Required Sample Size: 3781.93
# Effect size:  -0.13878662887183701
# Required Sample Size: 815.93
# Effect size:  -0.03602827944320552
# Required Sample Size: 12094.39
# Effect size:  0.029593994289321916
# Required Sample Size: 17924.73
# Effect size:  -0.04613968022288225
# Required Sample Size: 7374.69
# Effect size:  -0.16396521775760262
# Required Sample Size: 584.85
# Effect size:  0.05776371247489376
# Required Sample Size: 4705.60
# Effect size:  0.08267218570757216
# Required Sample Size: 2297.73
# Effect size:  0.04573838741034701
# Required Sample Size: 7504.65
# Effect size:  -0.04077145878402936
# Required Sample Size: 9444.27
# Effect size:  -0.09438343388104697
# Required Sample Size: 1763.12
# Effect size:  0.10839939169462082
# Required Sample Size: 1336.89
# Effect size:  0.041970960628665704
# Required Sample Size: 8912.21
# Effect size:  0.05734688438731964
# Required Sample Size: 4774.24
# Effect size:  -0.023115907252563784
# Required Sample Size: 29378.45
# Effect size:  0.010891649225834412
# Required Sample Size: 132328.22
# Effect size:  0.011303376507597523
# Required Sample Size: 122863.71
# Effect size:  0.01876197767556129
# Required Sample Size: 44595.26
# Effect size:  -0.01351991508888118
# Required Sample Size: 85880.30
# Effect size:  0.06298615483552639
# Required Sample Size: 3957.78
# Effect size:  -0.05062254544755806
# Required Sample Size: 6126.56
# Effect size:  0.02066333522542295
# Required Sample Size: 36766.06
# Effect size:  -0.14311904144917967
# Required Sample Size: 767.34
# Effect size:  0.1371965495086939
# Required Sample Size: 834.93
# Effect size:  0.16397211813861814
# Required Sample Size: 584.81
# Effect size:  0.1649856185697854
# Required Sample Size: 577.65
# Effect size:  0.08620099351279675
# Required Sample Size: 2113.54
# Effect size:  -0.04542189431995093
# Required Sample Size: 7609.58
# Effect size:  -0.005819385577419349
# Required Sample Size: 463535.76
# Effect size:  -0.1236998369340532
# Required Sample Size: 1026.85
# Effect size:  0.14811066883168858
# Required Sample Size: 716.55
# Effect size:  0.1340398813792848
# Required Sample Size: 874.67
# Effect size:  -0.005242896513392999
# Required Sample Size: 571077.14
# Effect size:  0.0449403209618361
# Required Sample Size: 7773.52
# Effect size:  0.12896470728230258
# Required Sample Size: 944.79
# Effect size:  0.019281599924048255
# Required Sample Size: 42224.10
# Effect size:  0.04180589286496004
# Required Sample Size: 8982.72
# Effect size:  -0.014829428416222205
# Required Sample Size: 71382.81
# Effect size:  0.19219452264074247
# Required Sample Size: 425.93
# Effect size:  -0.042650124120353634
# Required Sample Size: 8630.67
# Effect size:  -0.2113401717290638
# Required Sample Size: 352.42
# Effect size:  0.01075907758512365
# Required Sample Size: 135609.34
# Effect size:  0.010247058363973886
# Required Sample Size: 149499.93
# Effect size:  -0.06923705765450708
# Required Sample Size: 3275.57
# Effect size:  -0.0468741930574419
# Required Sample Size: 7145.41
# Effect size:  -0.20682663524734593
# Required Sample Size: 367.93
# Effect size:  -0.06871659305727464
# Required Sample Size: 3325.36
# Effect size:  0.06892857007863701
# Required Sample Size: 3304.95
# Effect size:  -0.2150443500508259
# Required Sample Size: 340.42
# Effect size:  -0.019699780918856755
# Required Sample Size: 40450.52
# Effect size:  0.1955247515249223
# Required Sample Size: 411.58
# Effect size:  0.06255010237321111
# Required Sample Size: 4013.14
# Effect size:  0.0886116448121427
# Required Sample Size: 2000.16
# Effect size:  0.20354635686984257
# Required Sample Size: 379.85
# Effect size:  0.0908868077359115
# Required Sample Size: 1901.32
# Effect size:  -0.08365869834542068
# Required Sample Size: 2243.88
# Effect size:  -0.05872935306340199
# Required Sample Size: 4552.16
# Effect size:  0.17614851587114197
# Required Sample Size: 506.88
# Effect size:  0.027319897984863062
# Required Sample Size: 21032.86
# Effect size:  0.08111273186013927
# Required Sample Size: 2386.90
# Effect size:  0.054254522525247144
# Required Sample Size: 5333.88
# Effect size:  -0.1998798259924971
# Required Sample Size: 393.88
# Effect size:  -0.0109421220897015
# Required Sample Size: 131110.26
# Effect size:  -0.054974168711954687
# Required Sample Size: 5195.17
# Effect size:  -0.18356215283917354
# Required Sample Size: 466.84
# Effect size:  0.014210565152317159
# Required Sample Size: 77735.48
# Effect size:  0.11631697818848365
# Required Sample Size: 1161.21
# Effect size:  -0.03611236477327361
# Required Sample Size: 12038.14
# Effect size:  -0.11110745696584928
# Required Sample Size: 1272.56
# Effect size:  -0.09531886732750593
# Required Sample Size: 1728.70
# Effect size:  0.11697366082326623
# Required Sample Size: 1148.22
# Effect size:  0.02706694161649948
# Required Sample Size: 21427.81
# Effect size:  -0.20280057493763481
# Required Sample Size: 382.64
# Effect size:  -0.13726215743188996
# Required Sample Size: 834.13
# Effect size:  -0.07310293518891782
# Required Sample Size: 2938.39
# Effect size:  -0.025423382224159654
# Required Sample Size: 24287.74
# Effect size:  -0.0901713950710184
# Required Sample Size: 1931.59
# Effect size:  -0.05449253330532023
# Required Sample Size: 5287.39
# Effect size:  0.009221601941097814
# Required Sample Size: 184597.63
# Effect size:  -0.1408726807879195
# Required Sample Size: 791.97
# Effect size:  -0.04129303414342724
# Required Sample Size: 9207.22
# Effect size:  -0.05730995982888927
# Required Sample Size: 4780.39
# Effect size:  0.0044107069183717505
# Required Sample Size: 806901.88
# Effect size:  0.056792936286553936
# Required Sample Size: 4867.81
# Effect size:  -0.05109004986701928
# Required Sample Size: 6014.97
# Effect size:  0.08566547847781375
# Required Sample Size: 2140.03
# Effect size:  0.03580331624273232
# Required Sample Size: 12246.84
# Effect size:  0.1677863817835189
# Required Sample Size: 558.56
# Effect size:  0.16512978447278195
# Required Sample Size: 576.65
# Effect size:  -0.039040310711399025
# Required Sample Size: 10300.32
# Effect size:  -0.10501559628641696
# Required Sample Size: 1424.37
# Effect size:  -0.025991972546077425
# Required Sample Size: 23236.79
# Effect size:  0.11400458861899154
# Required Sample Size: 1208.75
# Effect size:  0.13073611216907796
# Required Sample Size: 919.39
# Effect size:  0.06842384184243704
# Required Sample Size: 3353.87
# Effect size:  0.07814094389259826
# Required Sample Size: 2571.83
# Effect size:  0.055964305677631755
# Required Sample Size: 5013.00
# Effect size:  -0.021895152278039284
# Required Sample Size: 32745.63
# Effect size:  0.13622979527353496
# Required Sample Size: 846.81
# Effect size:  -0.13875256542185072
# Required Sample Size: 816.33
# Effect size:  0.03200153554464435
# Required Sample Size: 15329.30
# Effect size:  -0.0780394701212508
# Required Sample Size: 2578.52
# Effect size:  0.12422430846226824
# Required Sample Size: 1018.20
# Effect size:  0.11656459303990947
# Required Sample Size: 1156.28
# Effect size:  0.14388829852513896
# Required Sample Size: 759.16
# Effect size:  -0.04541101719519816
# Required Sample Size: 7613.23
# Effect size:  -0.049142726703394604
# Required Sample Size: 6501.03
# Effect size:  0.03505504455285831
# Required Sample Size: 12775.21
# Effect size:  -0.1525528781285599
# Required Sample Size: 675.48
# Effect size:  -0.16981185351133932
# Required Sample Size: 545.34
# Effect size:  -0.0446613339858959
# Required Sample Size: 7870.93
# Effect size:  0.04541986095092955
# Required Sample Size: 7610.27
# Effect size:  -0.17679378716436403
# Required Sample Size: 503.19
# Effect size:  0.006521460817022458
# Required Sample Size: 369103.33
# Effect size:  0.07895581748639575
# Required Sample Size: 2519.03
# Effect size:  0.038985600258154084
# Required Sample Size: 10329.24
# Effect size:  -0.13591439811614106
# Required Sample Size: 850.74
# Effect size:  -0.12157170091155432
# Required Sample Size: 1063.08
# Effect size:  -0.019906627032591336
# Required Sample Size: 39614.28
# Effect size:  0.03646582450531629
# Required Sample Size: 11805.92
# Effect size:  0.0005947357727223928
# Required Sample Size: 44380122.77
# Effect size:  -0.01888810062703916
# Required Sample Size: 44001.71
# Effect size:  0.0854545355011968
# Required Sample Size: 2150.60
# Effect size:  -0.11766651876258791
# Required Sample Size: 1134.75
# Effect size:  0.07473890483967693
# Required Sample Size: 2811.20
# Effect size:  0.08378213948637364
# Required Sample Size: 2237.28
# Effect size:  0.009962353444323363
# Required Sample Size: 158166.81
# Effect size:  -0.014798329918793776
# Required Sample Size: 71683.14
# Effect size:  -0.07055129303982656
# Required Sample Size: 3154.71
# Effect size:  -0.0530537930428997
# Required Sample Size: 5578.00
# Effect size:  0.17836171209881183
# Required Sample Size: 494.40
# Effect size:  -0.12079926733971813
# Required Sample Size: 1076.70
# Effect size:  -0.01809881666302439
# Required Sample Size: 47923.11
# Effect size:  0.027479283858005892
# Required Sample Size: 20789.59
# Effect size:  0.15304357447820632
# Required Sample Size: 671.16
# Effect size:  0.07766942652002602
# Required Sample Size: 2603.14
# Effect size:  0.13583591151591232
# Required Sample Size: 851.72
# Effect size:  0.0655020199318898
# Required Sample Size: 3659.66
# Effect size:  0.06081710908429599
# Required Sample Size: 4245.06
# Effect size:  -0.0059696416827186806
# Required Sample Size: 440495.05
# Effect size:  -0.06786176462816969
# Required Sample Size: 3409.64
# Effect size:  0.15252932651007264
# Required Sample Size: 675.69
# Effect size:  0.08487746268357643
# Required Sample Size: 2179.93
# Effect size:  -0.03196605999950884
# Required Sample Size: 15363.34
# Effect size:  0.00031269906645436756
# Required Sample Size: 160540069.89
# Effect size:  -0.18372594009492577
# Required Sample Size: 466.01
# Effect size:  0.02382150262546219
# Required Sample Size: 27663.90
# Effect size:  -0.02833330372789933
# Required Sample Size: 19555.26
# Effect size:  -0.07536386386429503
# Required Sample Size: 2764.78
# Effect size:  0.03085301415551467
# Required Sample Size: 16491.75
# Effect size:  0.1520591385764601
# Required Sample Size: 679.87
# Effect size:  -0.039142668497125985
# Required Sample Size: 10246.52
# Effect size:  0.038018145922192825
# Required Sample Size: 10861.58
# Effect size:  0.016145709813726684
# Required Sample Size: 60218.41
# Effect size:  0.15277556204119716
# Required Sample Size: 673.52
# Effect size:  -0.11369275520339316
# Required Sample Size: 1215.39
# Effect size:  0.12301731797845765
# Required Sample Size: 1038.26
# Effect size:  -0.10174533084249181
# Required Sample Size: 1517.34
# Effect size:  -0.25037459138336937
# Required Sample Size: 251.38
# Effect size:  -0.10399413781593025
# Required Sample Size: 1452.47
# Effect size:  -0.014898673004773681
# Required Sample Size: 70720.83
# Effect size:  0.00935757504875754
# Required Sample Size: 179271.93
# Effect size:  -0.14599558758477899
# Required Sample Size: 737.44
# Effect size:  0.07865232463275963
# Required Sample Size: 2538.50
# Effect size:  0.0041486059221236635
# Required Sample Size: 912079.52
# Effect size:  -0.0424658481753428
# Required Sample Size: 8705.72
# Effect size:  -0.08947814188822378
# Required Sample Size: 1961.62
# Effect size:  -0.034554557174138724
# Required Sample Size: 13147.94
# Effect size:  -0.073683349017984
# Required Sample Size: 2892.29
# Effect size:  -0.09769404918584393
# Required Sample Size: 1645.71
# Effect size:  0.04221718978207575
# Required Sample Size: 8808.57
# Effect size:  -0.08273276041776938
# Required Sample Size: 2294.37
# Effect size:  0.08873603370740812
# Required Sample Size: 1994.55
# Effect size:  -0.05388868602379485
# Required Sample Size: 5406.53
# Effect size:  -0.03022891731436255
# Required Sample Size: 17179.71
# Effect size:  0.06892762529868833
# Required Sample Size: 3305.04
# Effect size:  -0.13926107796188425
# Required Sample Size: 810.39
# Effect size:  -0.027211195485057196
# Required Sample Size: 21201.23
# Effect size:  0.12620105148653776
# Required Sample Size: 986.58
# Effect size:  -0.08862942542511389
# Required Sample Size: 1999.35
# Effect size:  0.12289443341472925
# Required Sample Size: 1040.34
# Effect size:  -0.00948291672057239
# Required Sample Size: 174564.18
# Effect size:  0.08074828093204006
# Required Sample Size: 2408.48
# Effect size:  0.09700264373165228
# Required Sample Size: 1669.24
# Effect size:  0.020378469615312568
# Required Sample Size: 37801.11
# Effect size:  0.10068912971692505
# Required Sample Size: 1549.32
# Effect size:  0.15092948556354538
# Required Sample Size: 690.07
# Effect size:  -0.018377632010692653
# Required Sample Size: 46480.04
# Effect size:  -0.017799126667936423
# Required Sample Size: 49550.45
# Effect size:  0.11197115312465288
# Required Sample Size: 1253.02
# Effect size:  0.15531984906647245
# Required Sample Size: 651.66
# Effect size:  -0.07037718224043796
# Required Sample Size: 3170.33
# Effect size:  0.023987984522702763
# Required Sample Size: 27281.26
# Effect size:  0.07631468291002355
# Required Sample Size: 2696.34
# Effect size:  -0.04133007873744236
# Required Sample Size: 9190.72
# Effect size:  0.14502805551673095
# Required Sample Size: 747.29
# Effect size:  0.0016234039513774155
# Required Sample Size: 5956394.93
# Effect size:  0.06623024205801759
# Required Sample Size: 3579.65
# Effect size:  -0.18701764154227657
# Required Sample Size: 449.78
# Effect size:  0.04436924393443117
# Required Sample Size: 7974.89
# Effect size:  0.06324836290275353
# Required Sample Size: 3925.04
# Effect size:  -0.016819873850924524
# Required Sample Size: 55487.95
# Effect size:  0.1807704854167125
# Required Sample Size: 481.34
# Effect size:  -0.005700190932836606
# Required Sample Size: 483124.06
# Effect size:  0.18371173898238438
# Required Sample Size: 466.08
# Effect size:  0.07081565306305054
# Required Sample Size: 3131.20
# Effect size:  -0.04495317361495367
# Required Sample Size: 7769.08
# Effect size:  -0.18449888723825364
# Required Sample Size: 462.12
# Effect size:  -0.07805800413039966
# Required Sample Size: 2577.29
# Effect size:  -0.12966169451275933
# Required Sample Size: 934.67
# Effect size:  0.10625855254628398
# Required Sample Size: 1391.26
# Effect size:  0.0612575770228504
# Required Sample Size: 4184.24
# Effect size:  0.02729801132533678
# Required Sample Size: 21066.60
# Effect size:  0.12386040111806175
# Required Sample Size: 1024.19
# Effect size:  0.000898141136600805
# Required Sample Size: 19460207.08
# Effect size:  -0.1055716242145977
# Required Sample Size: 1409.41
# Effect size:  0.06877457240477738
# Required Sample Size: 3319.76
# Effect size:  -0.06744513736930753
# Required Sample Size: 3451.88
# Effect size:  -0.1264722989064583
# Required Sample Size: 982.36
# Effect size:  -0.030322872556885264
# Required Sample Size: 17073.41
# Effect size:  -0.05590787390562657
# Required Sample Size: 5023.12
# Effect size:  -0.10259554961563279
# Required Sample Size: 1492.31
# Effect size:  -0.03806831811377721
# Required Sample Size: 10832.97
# Effect size:  -0.04203671918634978
# Required Sample Size: 8884.36
# Effect size:  0.04526632400058649
# Required Sample Size: 7661.97
# Effect size:  -0.0979917100602019
# Required Sample Size: 1635.74
# Effect size:  -0.2611715543230123
# Required Sample Size: 231.10
# Effect size:  0.05054575162479311
# Required Sample Size: 6145.19
# Effect size:  -0.052435539146846524
# Required Sample Size: 5710.29
# Effect size:  0.17701215884755664
# Required Sample Size: 501.95
# Effect size:  -0.056598411250084364
# Required Sample Size: 4901.32
# Effect size:  -0.00960003491817255
# Required Sample Size: 170330.90
# Effect size:  -0.11824003688631583
# Required Sample Size: 1123.77
# Effect size:  -0.08656807842605807
# Required Sample Size: 2095.66
# Effect size:  -0.0017133516777827987
# Required Sample Size: 5347412.20
# Effect size:  -0.028473985396278014
# Required Sample Size: 19362.51
# Effect size:  -0.2201631693368936
# Required Sample Size: 324.82
# Effect size:  0.08300638757926425
# Required Sample Size: 2279.27
# Effect size:  0.07661829179750183
# Required Sample Size: 2675.02
# Effect size:  0.027177414954785126
# Required Sample Size: 21253.96
# Effect size:  -0.055262682293900384
# Required Sample Size: 5141.07
# Effect size:  0.017236769379744145
# Required Sample Size: 52836.34
# Effect size:  0.04748435765250718
# Required Sample Size: 6962.98
# Effect size:  -0.1743908359299436
# Required Sample Size: 517.13
# Effect size:  0.1878538373401826
# Required Sample Size: 445.79
# Effect size:  -0.053926353313956364
# Required Sample Size: 5398.98
# Effect size:  0.18247852841452944
# Required Sample Size: 472.39
# Effect size:  -0.003788053234933562
# Required Sample Size: 1093968.57
# Effect size:  0.046378467660114484
# Required Sample Size: 7298.96
# Effect size:  -0.015265934606875422
# Required Sample Size: 67359.06
# Effect size:  0.04379863865138928
# Required Sample Size: 8184.01
# Effect size:  0.007923823827791866
# Required Sample Size: 250016.49
# Effect size:  -0.005958348186932113
# Required Sample Size: 442166.46
# Effect size:  0.01104024792626931
# Required Sample Size: 128790.02
# Effect size:  0.07584285627225597
# Required Sample Size: 2729.98
# Effect size:  -0.040206992039439164
# Required Sample Size: 9711.28
# Effect size:  -0.11175988866004205
# Required Sample Size: 1257.76
# Effect size:  0.06151058847012673
# Required Sample Size: 4149.90
# Effect size:  -0.0009179860982805367
# Required Sample Size: 18627922.68
# Effect size:  0.054083794721585136
# Required Sample Size: 5367.60
# Effect size:  0.04406728059023587
# Required Sample Size: 8084.55
# Effect size:  0.0781564949425197
# Required Sample Size: 2570.80
# Effect size:  -0.06540981786855486
# Required Sample Size: 3669.99
# Effect size:  0.04275320790031925
# Required Sample Size: 8589.10
# Effect size:  -0.09672812189024498
# Required Sample Size: 1678.73
# Effect size:  -0.14610598011161324
# Required Sample Size: 736.32
# Effect size:  -0.029235488739474156
# Required Sample Size: 18367.02
# Effect size:  0.021103585883106526
# Required Sample Size: 35248.12
# Effect size:  -0.05537565364032298
# Required Sample Size: 5120.12
# Effect size:  -0.002364236514675454
# Required Sample Size: 2808373.85
# Effect size:  0.013003308175952572
# Required Sample Size: 92839.63
# Effect size:  0.046862090868237526
# Required Sample Size: 7149.10
# Effect size:  0.08477456286520318
# Required Sample Size: 2185.23
# Effect size:  -0.008220093040015827
# Required Sample Size: 232319.11
# Effect size:  0.0008672711580321793
# Required Sample Size: 20870210.30
# Effect size:  0.107880930510404
# Required Sample Size: 1349.76
# Effect size:  0.049140722833870526
# Required Sample Size: 6501.56
# Effect size:  0.0033511340380203776
# Required Sample Size: 1397826.64
# Effect size:  0.03309574883779141
# Required Sample Size: 14332.48
# Effect size:  -0.02606915129704536
# Required Sample Size: 23099.41
# Effect size:  -0.13561868571260985
# Required Sample Size: 854.45
# Effect size:  0.1353137910167569
# Required Sample Size: 858.30
# Effect size:  -0.028491421544224575
# Required Sample Size: 19338.82
# Effect size:  -0.03430258906248385
# Required Sample Size: 13341.79
# Effect size:  0.20369359917794638
# Required Sample Size: 379.30
# Effect size:  -0.09118673618358916
# Required Sample Size: 1888.84
# Effect size:  -0.17951712238209663
# Required Sample Size: 488.07
# Effect size:  -0.19137955676173926
# Required Sample Size: 429.56
# Effect size:  -0.07504949948105369
# Required Sample Size: 2787.99
# Effect size:  0.017142669403191143
# Required Sample Size: 53417.99
# Effect size:  0.07220693575926461
# Required Sample Size: 3011.74
# Effect size:  0.04325141083182066
# Required Sample Size: 8392.39
# Effect size:  -0.01733074844158219
# Required Sample Size: 52264.88
# Effect size:  0.1320493735458163
# Required Sample Size: 901.21
# Effect size:  -0.04080032480493208
# Required Sample Size: 9430.91
# Effect size:  0.04236655054253811
# Required Sample Size: 8746.58
# Effect size:  -0.05220503529602518
# Required Sample Size: 5760.82
# Effect size:  0.06168277692540317
# Required Sample Size: 4126.77
# Effect size:  -0.07492190413185978
# Required Sample Size: 2797.49
# Effect size:  -0.0689335325461051
# Required Sample Size: 3304.47
# Effect size:  -0.06744173186497475
# Required Sample Size: 3452.23
# Effect size:  0.13850269789137842
# Required Sample Size: 819.28
# Effect size:  0.04142742400290355
# Required Sample Size: 9147.58
# Effect size:  -0.05994371020928941
# Required Sample Size: 4369.63
# Effect size:  -0.08754422799388496
# Required Sample Size: 2049.20
# Effect size:  0.07996536169975071
# Required Sample Size: 2455.86
# Effect size:  0.09192820152585947
# Required Sample Size: 1858.50
# Effect size:  0.24068802540256576
# Required Sample Size: 271.94
# Effect size:  -0.03627571640426943
# Required Sample Size: 11929.98
# Effect size:  0.16010404506736312
# Required Sample Size: 613.36
# Effect size:  0.0941472922811207
# Required Sample Size: 1771.97
# Effect size:  0.1707745771156672
# Required Sample Size: 539.22
# Effect size:  -0.17624674930720446
# Required Sample Size: 506.31
# Effect size:  -0.002219720497842856
# Required Sample Size: 3185958.83
# Effect size:  0.031111178197335394
# Required Sample Size: 16219.20
# Effect size:  -0.040660110932139754
# Required Sample Size: 9496.06
# Effect size:  -0.08531725582719037
# Required Sample Size: 2157.53
# Effect size:  -0.09765740260306578
# Required Sample Size: 1646.95
# Effect size:  0.06801687424664685
# Required Sample Size: 3394.11
# Effect size:  0.17341053457840241
# Required Sample Size: 522.98
# Effect size:  0.110325771764111
# Required Sample Size: 1290.64
# Effect size:  -0.062230594402664666
# Required Sample Size: 4054.45
# Effect size:  -0.06874106682221458
# Required Sample Size: 3322.99
# Effect size:  -0.0003604358147719383
# Required Sample Size: 120831659.65
# Effect size:  0.04154663720154407
# Required Sample Size: 9095.17
# Effect size:  -0.016419727046218077
# Required Sample Size: 58225.32
# Effect size:  -0.050059292595335696
# Required Sample Size: 6265.18
# Effect size:  -0.018810389380357888
# Required Sample Size: 44366.02
# Effect size:  -0.02670266550221224
# Required Sample Size: 22016.40
# Effect size:  -0.04785730427617523
# Required Sample Size: 6854.90
# Effect size:  -0.010552910924641216
# Required Sample Size: 140959.72
# Effect size:  -0.07509021335124096
# Required Sample Size: 2784.97
# Effect size:  -0.07748030725584693
# Required Sample Size: 2615.85
# Effect size:  -0.07194803075627378
# Required Sample Size: 3033.45
# Effect size:  -0.036614811393635496
# Required Sample Size: 11710.05
# Effect size:  -0.09812980799381663
# Required Sample Size: 1631.14
# Effect size:  -0.02923001064538376
# Required Sample Size: 18373.90
# Effect size:  0.1478275189435558
# Required Sample Size: 719.29
# Effect size:  0.13771242423649582
# Required Sample Size: 828.69
# Effect size:  -0.17823066926264505
# Required Sample Size: 495.13
# Effect size:  -0.06661823102310944
# Required Sample Size: 3538.09
# Effect size:  0.1403240719120622
# Required Sample Size: 798.17
# Effect size:  -0.08804956384633232
# Required Sample Size: 2025.76
# Effect size:  0.031101617955568088
# Required Sample Size: 16229.17
# Effect size:  -0.007284286458730999
# Required Sample Size: 295844.83
# Effect size:  0.007162189625415027
# Required Sample Size: 306017.56
# Effect size:  -0.002157431861571727
# Required Sample Size: 3372582.33
# Effect size:  0.030622643544232806
# Required Sample Size: 16740.80
# Effect size:  -0.07278518476352218
# Required Sample Size: 2964.09
# Effect size:  0.0004518599069573847
# Required Sample Size: 76882766.43
# Effect size:  0.061880951290274704
# Required Sample Size: 4100.38
# Effect size:  0.020911447494887526
# Required Sample Size: 35898.81
# Effect size:  -0.03687672671502012
# Required Sample Size: 11544.31
# Effect size:  -0.012119052487608438
# Required Sample Size: 106881.66
# Effect size:  0.1715167535227476
# Required Sample Size: 534.57
# Effect size:  -0.1018203265645396
# Required Sample Size: 1515.11
# Effect size:  -0.06725932311962729
# Required Sample Size: 3470.98
# Effect size:  0.05130134561921573
# Required Sample Size: 5965.53
# Effect size:  -0.03498407449000007
# Required Sample Size: 12827.10
# Effect size:  0.09437815916035903
# Required Sample Size: 1763.32
# Effect size:  -0.0506609212960837
# Required Sample Size: 6117.28
# Effect size:  -0.05679722780043603
# Required Sample Size: 4867.08
# Effect size:  0.07537748189791306
# Required Sample Size: 2763.79
# Effect size:  -0.0703068062132086
# Required Sample Size: 3176.68
# Effect size:  0.062369215892876174
# Required Sample Size: 4036.45
# Effect size:  0.0765022262956467
# Required Sample Size: 2683.14
# Effect size:  -0.05423983688162897
# Required Sample Size: 5336.76
# Effect size:  -0.035778728980325795
# Required Sample Size: 12263.68
# Effect size:  -0.08574011954030268
# Required Sample Size: 2136.31
# Effect size:  0.15804661186074115
# Required Sample Size: 629.41
# Effect size:  -0.11418092349706935
# Required Sample Size: 1205.02
# Effect size:  -0.11361389662924992
# Required Sample Size: 1217.07
# Effect size:  -0.052115181595313934
# Required Sample Size: 5780.70
# Effect size:  -0.0051563214410369025
# Required Sample Size: 590414.96
# Effect size:  0.20940463953113497
# Required Sample Size: 358.95
# Effect size:  -0.03361072427390717
# Required Sample Size: 13896.67
# Effect size:  0.08213422071875089
# Required Sample Size: 2327.92
# Effect size:  -0.0623586964599563
# Required Sample Size: 4037.81
# Effect size:  0.04537508352198059
# Required Sample Size: 7625.29
# Effect size:  -0.011982576906343656
# Required Sample Size: 109330.16
# Effect size:  -0.08788042951194161
# Required Sample Size: 2033.56
# Effect size:  -0.0234554355405306
# Required Sample Size: 28534.10
# Effect size:  -0.047190209580546434
# Required Sample Size: 7050.05
# Effect size:  -0.028642090957844604
# Required Sample Size: 19135.90
# Effect size:  -0.20812878333802878
# Required Sample Size: 363.35
# Effect size:  0.07337872225670333
# Required Sample Size: 2916.35
# Effect size:  -0.14927377141879541
# Required Sample Size: 705.44
# Effect size:  -0.003798667647448493
# Required Sample Size: 1087863.49
# Effect size:  -0.10744949586513587
# Required Sample Size: 1360.61
# Effect size:  -0.04930479803871398
# Required Sample Size: 6458.37
# Effect size:  0.028250821139761947
# Required Sample Size: 19669.61
# Effect size:  -0.027590799312327895
# Required Sample Size: 20621.88
# Effect size:  0.017104903748355132
# Required Sample Size: 53654.13
# Effect size:  -0.12017224788330079
# Required Sample Size: 1087.96
# Effect size:  -0.036169580502560014
# Required Sample Size: 12000.09
# Effect size:  -0.005369801618150161
# Required Sample Size: 544403.48
# Effect size:  -0.1332227856905377
# Required Sample Size: 885.42
# Effect size:  -0.030697227493031803
# Required Sample Size: 16659.55
# Effect size:  0.046550454213182976
# Required Sample Size: 7245.13
# Effect size:  0.13128355505477782
# Required Sample Size: 911.75
# Effect size:  -0.06759470365453638
# Required Sample Size: 3436.63
# Effect size:  -0.024281401800812584
# Required Sample Size: 26625.93
# Effect size:  0.03026663170650147
# Required Sample Size: 17136.92
# Effect size:  0.10178485978430268
# Required Sample Size: 1516.16
# Effect size:  -0.0848702860386331
# Required Sample Size: 2180.30
# Effect size:  -0.07403174844782867
# Required Sample Size: 2865.14
# Effect size:  -0.09637011725241355
# Required Sample Size: 1691.21
# Effect size:  0.038066566093478416
# Required Sample Size: 10833.97
# Effect size:  -0.0005824969000769717
# Required Sample Size: 46264661.00
# Effect size:  -0.1559180207367596
# Required Sample Size: 646.68
# Effect size:  -0.02821928053151192
# Required Sample Size: 19713.60
# Effect size:  -0.05373265927725467
# Required Sample Size: 5437.97
# Effect size:  -0.02530710100262235
# Required Sample Size: 24511.44
# Effect size:  0.06314840902234947
# Required Sample Size: 3937.47
# Effect size:  0.15754236280836123
# Required Sample Size: 633.43
# Effect size:  -0.05624296836528819
# Required Sample Size: 4963.46
# Effect size:  -0.006610252421330298
# Required Sample Size: 359254.06
# Effect size:  0.015294584528884174
# Required Sample Size: 67106.94
# Effect size:  0.03369383009697591
# Required Sample Size: 13828.21
# Effect size:  -0.07700557742286294
# Required Sample Size: 2648.19
# Effect size:  0.026146979869065733
# Required Sample Size: 22962.11
# Effect size:  0.05750211207124755
# Required Sample Size: 4748.50
# Effect size:  0.043557366517055565
# Required Sample Size: 8274.92
# Effect size:  0.02474509945997218
# Required Sample Size: 25637.43
# Effect size:  0.0164997368346221
# Required Sample Size: 57662.01
# Effect size:  -0.03425697057343722
# Required Sample Size: 13377.34
# Effect size:  -0.14994871331356782
# Required Sample Size: 699.12
# Effect size:  0.16016028972738516
# Required Sample Size: 612.93
# Effect size:  0.13495973474527648
# Required Sample Size: 862.80
# Effect size:  -0.02501366107441266
# Required Sample Size: 25089.89
# Effect size:  -0.06492751633938636
# Required Sample Size: 3724.70
# Effect size:  0.14908318689078912
# Required Sample Size: 707.25
# Effect size:  0.06089846891163158
# Required Sample Size: 4233.72
# Effect size:  -0.04067108529784887
# Required Sample Size: 9490.94
# Effect size:  -0.13585476095304244
# Required Sample Size: 851.49
# Effect size:  -0.08114467872802975
# Required Sample Size: 2385.02
# Effect size:  -0.18662703071675263
# Required Sample Size: 451.66
# Effect size:  -0.09235396163344735
# Required Sample Size: 1841.42
# Effect size:  -0.04811601230755394
# Required Sample Size: 6781.39
# Effect size:  0.023101503775745928
# Required Sample Size: 29415.10
# Effect size:  0.005203415709191066
# Required Sample Size: 579776.07
# Effect size:  0.0860082702813298
# Required Sample Size: 2123.01
# Effect size:  0.05418200758676561
# Required Sample Size: 5348.16
# Effect size:  -0.03324108325714693
# Required Sample Size: 14207.43
# Effect size:  -0.09156314424594837
# Required Sample Size: 1873.35
# Effect size:  -0.07290754394760228
# Required Sample Size: 2954.15
# Effect size:  0.010365975535244713
# Required Sample Size: 146089.54
# Effect size:  0.19059189985888803
# Required Sample Size: 433.11
# Effect size:  0.18716888940496196
# Required Sample Size: 449.06
# Effect size:  -0.006880363492802222
# Required Sample Size: 331600.45
# Effect size:  -0.008142947174732303
# Required Sample Size: 236741.91
# Effect size:  -0.04890091689298004
# Required Sample Size: 6565.47
# Effect size:  -0.3547102768534853
# Required Sample Size: 125.73
# Effect size:  -0.10804529107942924
# Required Sample Size: 1345.66
# Effect size:  -0.039646481389384564
# Required Sample Size: 9987.78
# Effect size:  0.27314511082099363
# Required Sample Size: 211.37
# Effect size:  -0.1045129386439011
# Required Sample Size: 1438.09
# Effect size:  0.09767605002034863
# Required Sample Size: 1646.32
# Effect size:  -0.06315614860522085
# Required Sample Size: 3936.51
# Effect size:  0.011299830790721792
# Required Sample Size: 122940.83
# Effect size:  0.04180474740298423
# Required Sample Size: 8983.22
# Effect size:  0.014208379155771132
# Required Sample Size: 77759.40
# Effect size:  0.08738631954120764
# Required Sample Size: 2056.61
# Effect size:  -0.06969754175673283
# Required Sample Size: 3232.44
# Effect size:  -0.06482688625689223
# Required Sample Size: 3736.27
# Effect size:  -0.1292107885778914
# Required Sample Size: 941.20
# Effect size:  -0.3033644982971064
# Required Sample Size: 171.54
# Effect size:  -0.03256782993011462
# Required Sample Size: 14800.87
# Effect size:  -0.04537610899351874
# Required Sample Size: 7624.95
# Effect size:  -0.05899156870188934
# Required Sample Size: 4511.79
# Effect size:  0.025396790920745527
# Required Sample Size: 24338.63
# Effect size:  0.12430766867390741
# Required Sample Size: 1016.84
# Effect size:  -0.04034174516224661
# Required Sample Size: 9646.52
# Effect size:  0.16249578550884825
# Required Sample Size: 595.46
# Effect size:  -0.018399352267618924
# Required Sample Size: 46370.37
# Effect size:  0.18496353405312346
# Required Sample Size: 459.81
# Effect size:  -0.11686499769327248
# Required Sample Size: 1150.35
# Effect size:  0.07108473488679974
# Required Sample Size: 3107.55
# Effect size:  -0.13084439834281447
# Required Sample Size: 917.87
# Effect size:  0.03077414384697392
# Required Sample Size: 16576.38
# Effect size:  0.011300025567795307
# Required Sample Size: 122936.59
# Effect size:  0.018940023676643353
# Required Sample Size: 43760.79
# Effect size:  0.0663683130509467
# Required Sample Size: 3564.77
# Effect size:  0.037880217440174994
# Required Sample Size: 10940.82
# Effect size:  0.08580451903366257
# Required Sample Size: 2133.10
# Effect size:  0.08195682827853105
# Required Sample Size: 2338.00
# Effect size:  0.05347478777318989
# Required Sample Size: 5490.53
# Effect size:  0.146649773222559
# Required Sample Size: 730.88
# Effect size:  -0.01907496599948575
# Required Sample Size: 43143.83
# Effect size:  0.10065771198775496
# Required Sample Size: 1550.29
# Effect size:  -0.09275339662191792
# Required Sample Size: 1825.60
# Effect size:  -0.0008784547554402397
# Required Sample Size: 20342196.12
# Effect size:  0.02665309023174651
# Required Sample Size: 22098.38
# Effect size:  -0.05113510486445934
# Required Sample Size: 6004.37
# Effect size:  -0.03479726897821147
# Required Sample Size: 12965.18
# Effect size:  -0.1126136848284576
# Required Sample Size: 1238.77
# Effect size:  0.023447145261875278
# Required Sample Size: 28554.28
# Effect size:  0.16061889344253116
# Required Sample Size: 609.44
# Effect size:  0.053493970128921375
# Required Sample Size: 5486.60
# Effect size:  -0.15053842408558926
# Required Sample Size: 693.66
# Effect size:  0.12114488420974764
# Required Sample Size: 1070.57
# Effect size:  -0.04515641244828688
# Required Sample Size: 7699.31
# Effect size:  0.007561138307428239
# Required Sample Size: 274576.75
# Effect size:  0.05491003926525114
# Required Sample Size: 5207.31
# Effect size:  0.042846360745897656
# Required Sample Size: 8551.80
# Effect size:  -0.06960420380791836
# Required Sample Size: 3241.11
# Effect size:  0.07961322380219649
# Required Sample Size: 2477.62
# Effect size:  0.06870090997425828
# Required Sample Size: 3326.88
# Effect size:  0.04817170687648049
# Required Sample Size: 6765.72
# Effect size:  0.08156096660343215
# Required Sample Size: 2360.74
# Effect size:  -0.005914419932310941
# Required Sample Size: 448759.06
# Effect size:  0.09845525671354481
# Required Sample Size: 1620.38
# Effect size:  -0.05409209632117268
# Required Sample Size: 5365.95
# Effect size:  0.08711014399802805
# Required Sample Size: 2069.67
# Effect size:  0.1551814224318896
# Required Sample Size: 652.83
# Effect size:  0.11688296380096502
# Required Sample Size: 1150.00
# Effect size:  -0.04128259762839861
# Required Sample Size: 9211.87
# Effect size:  0.11983695053431692
# Required Sample Size: 1094.05
# Effect size:  0.10736403986286376
# Required Sample Size: 1362.78
# Effect size:  -0.028501772154478407
# Required Sample Size: 19324.78
# Effect size:  -0.07469836763396293
# Required Sample Size: 2814.25
# Effect size:  0.03525899999795904
# Required Sample Size: 12627.86
# Effect size:  0.17027057020199493
# Required Sample Size: 542.41
# Effect size:  -0.09924320890566109
# Required Sample Size: 1594.77
# Effect size:  0.06481461492707016
# Required Sample Size: 3737.68
# Effect size:  -0.005936181596977387
# Required Sample Size: 445474.85
# Effect size:  -0.14238769492783848
# Required Sample Size: 775.23
# Effect size:  -0.09084513696554827
# Required Sample Size: 1903.06
# Effect size:  -0.13964526084406026
# Required Sample Size: 805.94
# Effect size:  0.00652151509401631
# Required Sample Size: 369097.19
# Effect size:  0.004809103766899571
# Required Sample Size: 678748.58
# Effect size:  0.14876766122641094
# Required Sample Size: 710.24
# Effect size:  -0.04293115851452562
# Required Sample Size: 8518.05
# Effect size:  0.16399702233719535
# Required Sample Size: 584.63
# Effect size:  0.15425884097932271
# Required Sample Size: 660.65
# Effect size:  0.21806142919643562
# Required Sample Size: 331.09
# Effect size:  0.06878038368452792
# Required Sample Size: 3319.20
# Effect size:  -0.03954317259810745
# Required Sample Size: 10040.03
# Effect size:  -0.012924522957064628
# Required Sample Size: 93974.93
# Effect size:  0.003208565229327373
# Required Sample Size: 1524807.93
# Effect size:  0.016908897239195857
# Required Sample Size: 54905.22
# Effect size:  -0.07885336584014739
# Required Sample Size: 2525.58
# Effect size:  -0.008785973186449001
# Required Sample Size: 203356.90
# Effect size:  0.11436473706542846
# Required Sample Size: 1201.16
# Effect size:  0.023583890649384515
# Required Sample Size: 28224.12
# Effect size:  0.007897201221984392
# Required Sample Size: 251705.01
# Effect size:  -0.1200316196575345
# Required Sample Size: 1090.51
# Effect size:  -0.010266611508345245
# Required Sample Size: 148931.02
# Effect size:  -0.03887324659278459
# Required Sample Size: 10389.03
# Effect size:  0.08336187666413084
# Required Sample Size: 2259.88
# Effect size:  0.03642304548213267
# Required Sample Size: 11833.67
# Effect size:  0.0923506456961751
# Required Sample Size: 1841.55
# Effect size:  0.0394517714103873
# Required Sample Size: 10086.60
# Effect size:  -0.08623010774047242
# Required Sample Size: 2112.11
# Effect size:  0.08872297499388525
# Required Sample Size: 1995.14
# Effect size:  0.0020859591543844615
# Required Sample Size: 3607656.07
# Effect size:  0.0764518208783057
# Required Sample Size: 2686.68
# Effect size:  0.003685749898335372
# Required Sample Size: 1155540.71
# Effect size:  0.05874192864976625
# Required Sample Size: 4550.21
# Effect size:  0.05124485075378499
# Required Sample Size: 5978.69
# Effect size:  0.0523096889083288
# Required Sample Size: 5737.80
# Effect size:  -0.05114381712386726
# Required Sample Size: 6002.33
# Effect size:  0.07070535714289623
# Required Sample Size: 3140.98
# Effect size:  -0.07186041298917772
# Required Sample Size: 3040.85
# Effect size:  0.052189713855195545
# Required Sample Size: 5764.20
# Effect size:  -0.05781079852241462
# Required Sample Size: 4697.94
# Effect size:  -0.08249521600905109
# Required Sample Size: 2307.60
# Effect size:  -0.006272112658307868
# Required Sample Size: 399034.05
# Effect size:  -0.0787042873693265
# Required Sample Size: 2535.15
# Effect size:  0.03045707420220998
# Required Sample Size: 16923.29
# Effect size:  0.10625209103938667
# Required Sample Size: 1391.43
# Effect size:  0.18279179857824449
# Required Sample Size: 470.77
# Effect size:  -0.07359450409875015
# Required Sample Size: 2899.28
# Effect size:  0.1571808921297067
# Required Sample Size: 636.35
# Effect size:  0.14462879765590503
# Required Sample Size: 751.42
# Effect size:  -0.028236949166256724
# Required Sample Size: 19688.94
# Effect size:  0.02048785712949737
# Required Sample Size: 37398.54
# Effect size:  0.0015990767262446
# Required Sample Size: 6139006.26
# Effect size:  0.06944805497552864
# Required Sample Size: 3255.70
# Effect size:  -0.045487117134220954
# Required Sample Size: 7587.78
# Effect size:  -0.1337641199202117
# Required Sample Size: 878.28
# Effect size:  0.01598962321580966
# Required Sample Size: 61399.80
# Effect size:  -0.05686396621175425
# Required Sample Size: 4855.66
# Effect size:  -0.07406348523668178
# Required Sample Size: 2862.69
# Effect size:  0.17062027170466965
# Required Sample Size: 540.19
# Effect size:  0.06921102184800842
# Required Sample Size: 3278.03
# Effect size:  -0.04289446668178681
# Required Sample Size: 8532.63
# Effect size:  -0.030314357056433178
# Required Sample Size: 17083.01
# Effect size:  0.19355310284851224
# Required Sample Size: 419.98
# Effect size:  -0.02115790662834356
# Required Sample Size: 35067.36
# Effect size:  0.14426566738550092
# Required Sample Size: 755.20
# Effect size:  0.2361886898919786
# Required Sample Size: 282.36
# Effect size:  -0.025860135012342505
# Required Sample Size: 23474.31
# Effect size:  -0.019251747610810967
# Required Sample Size: 42355.14
# Effect size:  -0.025158762858800556
# Required Sample Size: 24801.32
# Effect size:  0.12884960188171302
# Required Sample Size: 946.48
# Effect size:  -0.19626356712471807
# Required Sample Size: 408.49
# Effect size:  -0.07852370309480282
# Required Sample Size: 2546.82
# Effect size:  0.009714647969489051
# Required Sample Size: 166335.51
# Effect size:  0.14318136433530815
# Required Sample Size: 766.67
# Effect size:  0.07102766624213416
# Required Sample Size: 3112.54
# Effect size:  -0.12168550623444793
# Required Sample Size: 1061.09
# Effect size:  -0.06940143491160246
# Required Sample Size: 3260.08
# Effect size:  0.007856159927993298
# Required Sample Size: 254341.73
# Effect size:  0.07643543802832954
# Required Sample Size: 2687.83
# Effect size:  -0.005057594492420602
# Required Sample Size: 613690.33
# Effect size:  0.047953243840897594
# Required Sample Size: 6827.50
# Effect size:  -0.14739958761569139
# Required Sample Size: 723.47
# Effect size:  0.16651378616011323
# Required Sample Size: 567.12
# Effect size:  0.007483255000836342
# Required Sample Size: 280321.89
# Effect size:  0.1250949449184054
# Required Sample Size: 1004.09
# Effect size:  0.10869371025955887
# Required Sample Size: 1329.66
# Effect size:  -0.0363999387924485
# Required Sample Size: 11848.69
# Effect size:  0.10556616834748593
# Required Sample Size: 1409.56
# Effect size:  0.06034344792282737
# Required Sample Size: 4311.94
# Effect size:  -0.1354539802757455
# Required Sample Size: 856.53
# Effect size:  -0.07138566808244119
# Required Sample Size: 3081.41
# Effect size:  0.07756540075542137
# Required Sample Size: 2610.12
# Effect size:  -0.025737849255815997
# Required Sample Size: 23697.89
# Effect size:  0.0012797352895026492
# Required Sample Size: 9585093.73
# Effect size:  -0.044481143956873456
# Required Sample Size: 7934.82
# Effect size:  0.039809528964922895
# Required Sample Size: 9906.14
# Effect size:  -0.13741974074359226
# Required Sample Size: 832.22
# Effect size:  -0.0372115617298536
# Required Sample Size: 11337.51
# Effect size:  0.026490688141407537
# Required Sample Size: 22370.14
# Effect size:  -0.048538136219059946
# ...
# Required Sample Size: 1804.30
# Effect size:  -0.11337679823101283
# Required Sample Size: 1222.17
# Effect size:  -0.09854446845508417
# Required Sample Size: 1617.45
# Effect size:  -0.10978428349524746
# Required Sample Size: 1303.40
# Effect size:  -0.015852931427161116
# Required Sample Size: 62463.19
# Effect size:  0.07222560969142783
# Required Sample Size: 3010.18
# Effect size:  -0.05087260055883587
# Required Sample Size: 6066.49
# Effect size:  -0.0047822040532793575
# Required Sample Size: 686405.91
# Effect size:  0.0532155534387056
# Required Sample Size: 5544.15
# Effect size:  -0.06286680040267438
# Required Sample Size: 3972.82
# Effect size:  0.10545606004095513
# Required Sample Size: 1412.50
# Effect size:  -0.07383870069645745
# Required Sample Size: 2880.14
# Effect size:  -0.016540798221500366
# Required Sample Size: 57376.09
# Effect size:  0.06193684598886943
# Required Sample Size: 4092.99
# Effect size:  -0.07447843099413377
# Required Sample Size: 2830.89
# Effect size:  0.05771462290843975
# Required Sample Size: 4713.61
# Effect size:  0.05828679995997875
# Required Sample Size: 4621.54
# Effect size:  -0.01581581304522091
# Required Sample Size: 62756.72
# Effect size:  -0.1349600714390487
# Required Sample Size: 862.80
# Effect size:  0.003466955707892864
# Required Sample Size: 1305991.49
# Effect size:  -0.012424438240831578
# Required Sample Size: 101692.09
# Effect size:  -0.0666540028023031
# Required Sample Size: 3534.29
# Effect size:  0.03156141340241773
# Required Sample Size: 15759.78
# Effect size:  0.021373820526278856
# Required Sample Size: 34362.47
# Effect size:  -0.05182256844848372
# Required Sample Size: 5846.15
# Effect size:  -0.13400714646664424
# Required Sample Size: 875.10
# Effect size:  -0.026694367776804027
# Required Sample Size: 22030.09
# Effect size:  -0.13428218095262084
# Required Sample Size: 871.52
# Effect size:  -0.03490384330831283
# Required Sample Size: 12886.13
# Effect size:  0.003887603789098716
# Required Sample Size: 1038659.08
# Effect size:  0.002025684316826197
# Required Sample Size: 3825543.90
# Effect size:  0.03645157326351666
# Required Sample Size: 11815.15
# Effect size:  0.043523377847627887
# Required Sample Size: 8287.85
# Effect size:  0.08932900334415364
# Required Sample Size: 1968.17
# Effect size:  -0.12305276234037478
# Required Sample Size: 1037.66
# Effect size:  -0.1338022044879931
# Required Sample Size: 877.78
# Effect size:  -0.0028357009312996754
# Required Sample Size: 1952162.54
# Effect size:  -0.11081279947816824
# Required Sample Size: 1279.33
# Effect size:  0.08930394010214764
# Required Sample Size: 1969.28
# Effect size:  0.0051193462493898485
# Required Sample Size: 598974.45
# Effect size:  0.18594170575896954
# Required Sample Size: 454.99
# Effect size:  -0.006749947460077566
# Required Sample Size: 344537.93
# Effect size:  0.05999608114137074
# Required Sample Size: 4362.01
# Effect size:  -0.17122303719121976
# Required Sample Size: 536.40
# Effect size:  0.045971782539006245
# Required Sample Size: 7428.65
# Effect size:  0.022881303896407617
# Required Sample Size: 29983.96
# Effect size:  0.020712924668865592
# Required Sample Size: 36590.23
# Effect size:  -0.038472638466520825
# Required Sample Size: 10606.50
# Effect size:  0.13979925584559152
# Required Sample Size: 804.17
# Effect size:  -0.13714107977642853
# Required Sample Size: 835.61
# Effect size:  0.14129276764856213
# Required Sample Size: 787.28
# Effect size:  0.1484934078422119
# Required Sample Size: 712.87
# Effect size:  0.08486735322718589
# Required Sample Size: 2180.45
# Effect size:  -0.15781386564604363
# Required Sample Size: 631.26
# Effect size:  -0.11717420888515942
# Required Sample Size: 1144.29
# Effect size:  -0.004664258367731357
# Required Sample Size: 721559.24
# Effect size:  -0.052089037874687466
# Required Sample Size: 5786.50
# Effect size:  -0.0858285503304198
# Required Sample Size: 2131.91
# Effect size:  0.19474017631889742
# Required Sample Size: 414.89
# Effect size:  -0.0679417900760084
# Required Sample Size: 3401.62
# Effect size:  0.09946423250656111
# Required Sample Size: 1587.69
# Effect size:  -0.06933177426783915
# Required Sample Size: 3266.63
# Effect size:  0.04223251965957599
# Required Sample Size: 8802.18
# Effect size:  -0.03497981963947039
# Required Sample Size: 12830.22
# Effect size:  0.07866406492556648
# Required Sample Size: 2537.75
# Effect size:  0.17996516440263816
# Required Sample Size: 485.65
# Effect size:  -0.04329007745038815
# Required Sample Size: 8377.41
# Effect size:  -0.0004633387616592866
# Required Sample Size: 73120533.52
# Effect size:  -0.143104246874028
# Required Sample Size: 767.50
# Effect size:  -0.00947451206318929
# Required Sample Size: 174874.02
# Effect size:  -0.014467582684272588
# Required Sample Size: 74998.09
# Effect size:  0.10405742779972038
# Required Sample Size: 1450.70
# Effect size:  0.006937509282272989
# Required Sample Size: 326160.03
# Effect size:  -0.02680446297154015
# Required Sample Size: 21849.50
# Effect size:  0.007106105691122248
# Required Sample Size: 310867.01
# Effect size:  0.025587897765465748
# Required Sample Size: 23976.45
# Effect size:  0.13205268006040294
# Required Sample Size: 901.17
# Effect size:  -0.09787130277069858
# Required Sample Size: 1639.76
# Effect size:  -0.14284836654151192
# Required Sample Size: 770.24
# Effect size:  -0.009907973688777492
# Required Sample Size: 159907.76
# Effect size:  0.07223836157968697
# Required Sample Size: 3009.12
# Effect size:  0.04837732448213286
# Required Sample Size: 6708.34
# Effect size:  -0.03152418405956603
# Required Sample Size: 15797.03
# Effect size:  -0.2169202613354777
# Required Sample Size: 334.57
# Effect size:  0.1382751818311037
# Required Sample Size: 821.97
# Effect size:  -0.14326825888742253
# Required Sample Size: 765.74
# Effect size:  0.07253645315654794
# Required Sample Size: 2984.45
# Effect size:  -0.006536098896886704
# Required Sample Size: 367451.92
# Effect size:  -0.02036994859568597
# Required Sample Size: 37832.74
# Effect size:  -0.11847090591724932
# Required Sample Size: 1119.40
# Effect size:  -0.14203372187131427
# Required Sample Size: 779.09
# Effect size:  -0.1391594585763944
# Required Sample Size: 811.57
# Effect size:  0.18837407455229618
# Required Sample Size: 443.34
# Effect size:  -0.009674408832525964
# Required Sample Size: 167722.08
# Effect size:  -0.05536935092547854
# Required Sample Size: 5121.29
# Effect size:  0.0038399861108440484
# Required Sample Size: 1064578.52
# Effect size:  -0.19924104468438714
# Required Sample Size: 396.40
# Effect size:  0.042259349284468714
# Required Sample Size: 8791.00
# Effect size:  -0.0018860540390389583
# Required Sample Size: 4412944.28
# Effect size:  0.12070951123906944
# Required Sample Size: 1078.30
# Effect size:  -0.09979654380390512
# Required Sample Size: 1577.14
# Effect size:  -0.011046416808101733
# Required Sample Size: 128646.21
# Effect size:  -0.016429272492909895
# Required Sample Size: 58157.69
# Effect size:  -0.0782775132781387
# Required Sample Size: 2562.86
# Effect size:  0.012089483741715331
# Required Sample Size: 107405.12
# Effect size:  0.006140520889926085
# Required Sample Size: 416319.92
# Effect size:  -0.0215011736049214
# Required Sample Size: 33956.63
# Effect size:  -0.10459099695888334
# Required Sample Size: 1435.95
# Effect size:  -0.049973113147591654
# Required Sample Size: 6286.81
# Effect size:  0.05284269173441452
# Required Sample Size: 5622.65
# Effect size:  0.06510215505340874
# Required Sample Size: 3704.75
# Effect size:  0.19813506586486884
# Required Sample Size: 400.83
# Effect size:  -0.07961075353766646
# Required Sample Size: 2477.77
# Effect size:  -0.22423065819737767
# Required Sample Size: 313.17
# Effect size:  0.1016802782355014
# Required Sample Size: 1519.28
# Effect size:  -0.13836767339594827
# Required Sample Size: 820.87
# Effect size:  -0.03316940181224378
# Required Sample Size: 14268.90
# Effect size:  -0.08395166043361837
# Required Sample Size: 2228.26
# Effect size:  -0.1488612033830172
# Required Sample Size: 709.35
# Effect size:  0.06593265237743358
# Required Sample Size: 3612.03
# Effect size:  -0.003985609329942517
# Required Sample Size: 988206.22
# Effect size:  0.09005168961541174
# Required Sample Size: 1936.73
# Effect size:  0.08459649282155589
# Required Sample Size: 2194.43
# Effect size:  0.1501171302244197
# Required Sample Size: 697.55
# Effect size:  -0.06256138503139329
# Required Sample Size: 4011.69
# Effect size:  -0.17283334754429094
# Required Sample Size: 526.47
# Effect size:  0.08611484720350536
# Required Sample Size: 2117.76
# Effect size:  0.20317096180764205
# Required Sample Size: 381.25
# Effect size:  -0.04354736042260793
# Required Sample Size: 8278.72
# Effect size:  -0.07182450585840859
# Required Sample Size: 3043.89
# Effect size:  0.15490899899460103
# Required Sample Size: 655.12
# Effect size:  0.041215988871108174
# Required Sample Size: 9241.67
# Effect size:  0.09564877826437584
# Required Sample Size: 1716.80
# Effect size:  -0.16532938404587358
# Required Sample Size: 575.26
# Effect size:  0.008723713776044055
# Required Sample Size: 206269.88
# Effect size:  -0.09222401653504801
# Required Sample Size: 1846.61
# Effect size:  0.19875604555170345
# Required Sample Size: 398.33
# Effect size:  0.13583052671260912
# Required Sample Size: 851.79
# Effect size:  -0.03184614134285826
# Required Sample Size: 15479.25
# Effect size:  -0.07780574725413124
# Required Sample Size: 2594.02
# Effect size:  -0.006184615826091695
# Required Sample Size: 410404.56
# Effect size:  0.1551826845800819
# Required Sample Size: 652.82
# Effect size:  0.03590401878411072
# Required Sample Size: 12178.25
# Effect size:  -0.0675261559149343
# Required Sample Size: 3443.61
# Effect size:  0.08549206342294237
# Required Sample Size: 2148.72
# Effect size:  -0.0834507347301041
# Required Sample Size: 2255.08
# Effect size:  -0.18208939628206097
# Required Sample Size: 474.40
# Effect size:  -0.1994717202870578
# Required Sample Size: 395.49
# Effect size:  -0.03604185478072957
# Required Sample Size: 12085.28
# Effect size:  -0.08204600548937706
# Required Sample Size: 2332.92
# Effect size:  -0.009567238330240603
# Required Sample Size: 171500.69
# Effect size:  -0.08258557931382814
# Required Sample Size: 2302.55
# Effect size:  0.039034683890535236
# Required Sample Size: 10303.29
# Effect size:  -0.11753189703930163
# Required Sample Size: 1137.35
# Effect size:  -0.013969172007129145
# Required Sample Size: 80445.26
# Effect size:  -0.017328678117486736
# Required Sample Size: 52277.37
# Effect size:  -0.23380372134490263
# Required Sample Size: 288.13
# Effect size:  -0.018859063972886236
# Required Sample Size: 44137.30
# Effect size:  -0.172730242794031
# Required Sample Size: 527.10
# Effect size:  0.020645221286042403
# Required Sample Size: 36830.61
# Effect size:  -0.1487179449586236
# Required Sample Size: 710.72
# Effect size:  -0.12670755418860616
# Required Sample Size: 978.72
# Effect size:  -0.14458660357890543
# Required Sample Size: 751.86
# Effect size:  0.015531750883689443
# Required Sample Size: 65073.20
# Effect size:  0.08504278393602627
# Required Sample Size: 2171.47
# Effect size:  0.06263528837763804
# Required Sample Size: 4002.24
# Effect size:  0.32216621218280084
# Required Sample Size: 152.21
# Effect size:  -0.04454345974033581
# Required Sample Size: 7912.64
# Effect size:  -0.14710528491949046
# Required Sample Size: 726.37
# Effect size:  0.22074259941458313
# Required Sample Size: 323.12
# Effect size:  -0.27282399112083827
# Required Sample Size: 211.86
# Effect size:  0.18319950643486907
# Required Sample Size: 468.68
# Effect size:  -0.06453697273314651
# Required Sample Size: 3769.90
# Effect size:  0.06802859946066024
# Required Sample Size: 3392.94
# Effect size:  0.10331088719844515
# Required Sample Size: 1471.73
# Effect size:  -0.2130212638895581
# Required Sample Size: 346.89
# Effect size:  -0.03927999181230857
# Required Sample Size: 10175.01
# Effect size:  -0.139457113350008
# Required Sample Size: 808.11
# Effect size:  -0.034602782482074435
# Required Sample Size: 13111.32
# Effect size:  0.06787732871347923
# Required Sample Size: 3408.08
# Effect size:  -0.3052170599976856
# Required Sample Size: 169.47
# Effect size:  0.053330952003463515
# Required Sample Size: 5520.18
# Effect size:  -0.08386862628481559
# Required Sample Size: 2232.67
# Effect size:  -0.09574060344816103
# Required Sample Size: 1713.51
# Effect size:  -0.051094493108126034
# Required Sample Size: 6013.92
# [3933.4884725093084, 865.6279439187391, 1503.138505034581, 712032.3177685365, 17940.749455557067, 15114.221590869167, 73137.63710258057, 464.3761841560477, 1493.4006494051434, 1456.0714501962336, 1343.3499190311522, 1096.9628749213286, 17020.073445676884, 1468.016086062836, 249.7857277438292, 2327.9938174288723, 4833.286108783183, 1530.7198143787348, 12743.819405217717, 572.865118528334, 8882.851788958924, 487.50165488656825, 201806.005389292, 213.97401337202524, 666.1647432440275, 8264.0769976086, 6710838.202001901, 2732.3181245072924, 47719.211670256795, 3799.407679644454, 4558.690227399427, 9935.870353599474, 27418.86727411184, 9332.623050052882, 6268.417284514198, 8008.345732013929, 65489.80767665953, 1197.4823658629393, 1873.4671460810391, 1303.4581426286206, 1862.2087550105402, 1315.3139726521372, 108609.17157919254, 2180.729271937289, 52619.63025002987, 1865449.9353617984, 6226.8955257414755, 1230.847264706806, 2166.3418137384297, 3521.9791551334483, 17372.72120449323, 360.1915764779255, 1518.4695248000412, 956.36305646964, 2261.6050666872284, 1961.9898751550882, 2406.2559816035878, 606569.721044541, 1708.719151031008, 367910.8998618655, 2002.138764828662, 23951.248945765583, 4982.846617488281, 4026.7369094700784, 3373.434347160467, 4526.7360597206725, 706.9476102478696, 406.96325673366505, 2662.989413535711, 13208.794467354974, 22273.51492198581, 70958748.09058496, 53105.0641275496, 836.0893335881544, 36270885.95069351, 208212.33113391808, 759.0269317211772, 5519.473657744385, 2768.4063696095095, 1076.6929231863169, 9396.338293666966, 661.1590478376438, 1521.2502858061275, 315.3106358126754, 21057.06189686048, 116299.58743096208, 11843.909953142553, 21356.05467823485, 474.9080794561135, 48345.18466830642, 3650646.0878111958, 1444.2563317162742, 3518205.016842481, 3138.908150460527, 6786.1857798757, 19336.761638943644, 2641.43929479662, 940.7777316699566, 497.7048092019869, 2612.358166665476, 1192.6996512626038, 5879846.957065433, 3261.7964154317947, 22787.736832249328, 134731140.77534732, 1110.7148225084322, 4605.295703305225, 987.6994984070789, 8884.925940606765, 277470668.9299314, 921.2824553498601, 13575.259827716656, 24103.41426783664, 3781.9287633979834, 815.9309815799146, 12094.392461331643, 17924.73368334902, 7374.694241926457, 584.8547581938068, 4705.600784679157, 2297.7321682927313, 7504.6510336383, 9444.26752503025, 1763.1197678247536, 1336.8886432994757, 8912.213878583565, 4774.241061424647, 29378.45304521077, 132328.22058244052, 122863.7084795229, 44595.263667892425, 85880.2977323508, 3957.7817396324253, 6126.560808634304, 36766.061956394515, 767.33733173833, 834.9310786393062, 584.8056158435492, 577.6546073002876, 2113.535472821286, 7609.5845716742915, 463535.7621251173, 1026.8454884693792, 716.5510752280605, 874.6738905267823, 571077.1351751568, 7773.523882009679, 944.7936749486222, 42224.09560623347, 8982.723778006315, 71382.80866919817, 425.92889926225337, 8630.666744610364, 352.42018402021165, 135609.3423910462, 149499.9278646328, 3275.5692998698337, 7145.41382938225, 367.92701427308776, 3325.361408982471, 3304.9456965161758, 340.4167249542491, 40450.5220857957, 411.57597665758027, 4013.14201798095, 2000.1551725831403, 379.8499625556912, 1901.3166097321841, 2243.88398782101, 4552.163271310514, 506.8784104546869, 21032.858377158856, 2386.8954566800007, 5333.8762679383435, 393.8777362802442, 131110.26089790656, 5195.167754369137, 466.83829579635, 77735.47884811893, 1161.2079751140363, 12038.140462704407, 1272.560135330755, 1728.7027938623928, 1148.2174474530145, 21427.806026821327, 382.6417201704004, 834.1340364000476, 2938.387001119632, 24287.741541271505, 1931.5907662065483, 5287.392123022398, 184597.63349510584, 791.9734765953921, 9207.215934860724, 4780.393850485421, 806901.8814237046, 4867.810616736178, 6014.967937326222, 2140.030424021591, 12246.84338217529, 558.5625410814814, 576.6480911024508, 10300.316741304174, 1424.3677065512138, 23236.78736745482, 1208.7525596434677, 919.3901236589351, 3353.8 ...

# %% [markdown]
# # Additional Resources

# %% [markdown]
# Power analysis introductions are [here](https://stats.idre.ucla.edu/other/mult-pkg/seminars/intro-power/) and [here](http://www.biostathandbook.com/power.html).
#
# Demonstrations are [here](https://demonstrations.wolfram.com/PowerAnalysisForATwoSampleTTest/) and [here](https://rpsychologist.com/d3/nhst/).
#
# Guidance for computing in [Matlab](https://www.mathworks.com/help/stats/sampsizepwr.html) (including a nice [tutorial](https://www.mathworks.com/help/stats/selecting-a-sample-size.html)\), [R](https://www.statmethods.net/stats/power.html), and [Python](https://www.geeksforgeeks.org/introduction-to-power-analysis-in-python/).

# %% [markdown]
# # Credits
#
# Copyright 2021 by Joshua I. Gold, University of Pennsylvania
